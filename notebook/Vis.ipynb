# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import csv
# %matplotlib inline

# %%
def rosenbrock2(x, y):
    value = (1 - x) ** 2 + 100 * (y - x ** 2) ** 2
    return value;

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('path.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 4997

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('path1.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 4997

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('path2.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 4978

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('path3.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 2695644

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('momentum-path1.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 595

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('momentum-path2.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 597

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('momentum-path3.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 825

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nag-path1.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 575

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nag-path2.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 587

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nag-path3.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 792

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nadam-path1.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 184

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nadam-path2.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 170

# %%
x = np.arange(-5.0,5.0,0.1)
y = np.arange(-5.0,10.0,0.1)
X,Y = np.meshgrid(x, y)
Z = rosenbrock2(X, Y)

with open('nadam-path3.csv', newline='') as csvfile:
    raw_csv = csv.reader(csvfile, delimiter='|')
    path = [[float(i.replace(',', '.')) for i in row] for row in raw_csv]
pathx, pathy = zip(*path)

plt.contourf(X, Y, Z, 250, cmap=plt.cm.coolwarm)
plt.plot(pathx, pathy, 'k', pathx, pathy, 'ro')
plt.show()

print(len(pathx))
# Out:
# 274
